# %%
import pandas as pd

df = pd.read_csv('../data/leads_dataset.csv')

print('First 5 rows:')
print(df.head())

print('\nCompanies by country:')
print(df['Country'].value_counts())

print('\nCompanies by industry:')
print(df['Industry'].value_counts())
# Out:
# First 5 rows:
#    Company Name              Website Country        Industry Contact Page  \
# 0      Nexus AI      www.nexusai.com     USA  AI Development          Yes
# 1  BrainCore AI  www.braincoreai.com  Canada  AI Development          Yes
# 2    Quantum AI    www.quantumai.com     UAE  AI Development          Yes
# 3   DeepMind AI   www.deepmindai.com     USA  AI Development          Yes
# 4     CogniTech    www.cognitech.com  Canada  AI Development          Yes
#
#                                   Company Services Contact Form Lead Quality
# 0  AI Development, Machine Learning, Deep Learning          Yes         High
# 1  AI Development, Machine Learning, Deep Learning          Yes         High
# 2  AI Development, Machine Learning, Deep Learning          Yes         High
# 3  AI Development, Machine Learning, Deep Learning          Yes         High
# 4  AI Development, Machine Learning, Deep Learning          Yes         High
#
# Companies by country:
# Country
# USA       17
# Canada    17
# UAE       16
# Name: count, dtype: int64
#
# Companies by industry:
# Industry
# AI Development    50
# Name: count, dtype: int64
